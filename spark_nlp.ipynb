# %%
# import sqlite3
# import matplotlib.pyplot as plt
# import numpy as np
import pandas as pd
import json
import statistics
import seaborn as sns
from datetime import datetime
import time
import matplotlib.pyplot as plt

import spacy
from spacytextblob.spacytextblob import SpacyTextBlob

# %%
df = pd.read_csv("renault.csv", sep=",")

# %%
sns.lineplot(x='post_date', y='polarity_spacy', data=df).set(xlabel=None)
# Out:
# [Text(0.5, 0, '')]

# %%
# Out:
#                    tweet_id           writer   post_date  \
# 9958    1141664555455660032     markbspiegel  2019-06-20
# 14127   1142558681734627328  AliceCh76224366  2019-06-22
# 99350   1160799622538911744         Alpsoy66  2019-08-12
# 105301  1162119123217899522         DZierler  2019-08-15
# 106536  1162414355314552832         DZierler  2019-08-16
# 107404  1162731497733971968         DZierler  2019-08-17
# 112951  1164092949627625472     WickedSplits  2019-08-21
# 186243  1179848356211806208    RtGT_Guinness  2019-10-03
# 194641  1181813406841458689    BertelSchmitt  2019-10-09
#
#                                                      body  comment_num  \
# 9958    "Renault, Nissan partner with Waymo for self-d...            0
# 14127   Waymo Just Partnered With Renault and Nissan t...            0
# 99350   I didn't know this! Norway and the Netherlands...            0
# 105301  With today’s announcement of Renault as an add...            0
# 106536  Automotive industry rapidly adopting #wearable...            1
# 107404  This is called “running away with the category...            0
# 112951  ▶︎ Fiat-Renault deal back on the radar https:/...            0
# 186243  "Why This $4,000 Renault Is as Disruptive as t...            0
# 194641  @Renault Mulls Bigger Electric Car to Compete ...            0
#
#         retweet_num  like_num
# 9958              2        21
# 14127             0         1
# 99350             1         4
# 105301            0         0
# 106536            0         1
# 107404            2         1
# 112951            0         0
# 186243            0         1
# 194641            0         1

# %%
# Out:
# 0.2
# /home/adrienfontaine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# 0.4000000000000001
# 0.1
# 0.8
# 0.10000000000000002
# 0.05
# 0.0
# 0.0
# 0.0
# 0.183

# %%
# Out:
#                    tweet_id           writer   post_date  \
# 9958    1141664555455660032     markbspiegel  2019-06-20
# 14127   1142558681734627328  AliceCh76224366  2019-06-22
# 99350   1160799622538911744         Alpsoy66  2019-08-12
# 105301  1162119123217899522         DZierler  2019-08-15
# 106536  1162414355314552832         DZierler  2019-08-16
# 107404  1162731497733971968         DZierler  2019-08-17
# 112951  1164092949627625472     WickedSplits  2019-08-21
# 186243  1179848356211806208    RtGT_Guinness  2019-10-03
# 194641  1181813406841458689    BertelSchmitt  2019-10-09
#
#                                                      body  comment_num  \
# 9958    "Renault, Nissan partner with Waymo for self-d...            0
# 14127   Waymo Just Partnered With Renault and Nissan t...            0
# 99350   I didn't know this! Norway and the Netherlands...            0
# 105301  With today’s announcement of Renault as an add...            0
# 106536  Automotive industry rapidly adopting #wearable...            1
# 107404  This is called “running away with the category...            0
# 112951  ▶︎ Fiat-Renault deal back on the radar https:/...            0
# 186243  "Why This $4,000 Renault Is as Disruptive as t...            0
# 194641  @Renault Mulls Bigger Electric Car to Compete ...            0
#
#         retweet_num  like_num  polarity_spacy
# 9958              2        21            0.20
# 14127             0         1            0.40
# 99350             1         4            0.10
# 105301            0         0            0.80
# 106536            0         1            0.10
# 107404            2         1            0.05
# 112951            0         0            0.00
# 186243            0         1            0.00
# 194641            0         1            0.00

# %%
df = pd.read_csv(name_csv, sep=",")
df
# Out:
#                tweet_id        writer   post_date  \
# 0   1141396957979709445    dividendc2  2019-06-19
# 1   1147018200598614016    dividendc2  2019-07-05
# 2   1147427014112153600    dividendc2  2019-07-06
# 3   1149959707328733184    dividendc2  2019-07-13
# 4   1154413492209934336  wallstsolver  2019-07-25
# 5   1157153766895828994    dividendc2  2019-08-02
# 6   1157674989627355136  wallstsolver  2019-08-03
# 7   1158037376071086084  wallstsolver  2019-08-04
# 8   1158399761998864385  wallstsolver  2019-08-05
# 9   1158762146223788033  wallstsolver  2019-08-06
# 10  1159124534857031680  wallstsolver  2019-08-07
# 11  1159486920721862658  wallstsolver  2019-08-08
# 12  1159849310370095104  wallstsolver  2019-08-09
# 13  1160211706263609344  wallstsolver  2019-08-10
# 14  1160574091440599040  wallstsolver  2019-08-11
# 15  1160936473807470593  wallstsolver  2019-08-12
# 16  1162386025987149824  wallstsolver  2019-08-16
# 17  1162748420601319426  wallstsolver  2019-08-17
# 18  1163110806998925312  wallstsolver  2019-08-18
# 19  1163473188879314945  wallstsolver  2019-08-19
# 20  1163835578300936192  wallstsolver  2019-08-20
# 21  1164046862212636672    dividendc2  2019-08-21
# 22  1164560352715116544  wallstsolver  2019-08-22
# 23  1164922740249419777  wallstsolver  2019-08-23
# 24  1165161126360956929      fuckCNBC  2019-08-24
# 25  1165285133102047233  wallstsolver  2019-08-24
# 26  1165647525380071433  wallstsolver  2019-08-25
# 27  1166009903749771264  wallstsolver  2019-08-26
# 28  1166372292353515523  wallstsolver  2019-08-27
# 29  1166734681557131266  wallstsolver  2019-08-28
# 30  1167097067635990528  wallstsolver  2019-08-29
# 31  1167201868696686592      fuckCNBC  2019-08-29
# 32  1167459455451226112  wallstsolver  2019-08-30
# 33  1169996170212466695  wallstsolver  2019-09-06
# 34  1173825608297648128    dividendc2  2019-09-17
# 35  1189646974229897216    dividendc2  2019-10-30
#
#                                                  body  comment_num  \
# 0   Mis TOP5 mejores compañías LARGE CAP GROWTH la...            0
# 1   MY TOP10 ------- best companies in the world -...            0
# 2   ETF de PFM Invesco Dividend Achievers Princ Po...            1
# 3   MY TOP5 best companies long term              ...            0
# 4    Conservative Buy Rankings  $AMZN  http://Amaz...            0
# 5   Mis TOP5 mejores compañías LARGE CAP GROWTH la...            0
# 6    Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 7    Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 8    Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 9    Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 10   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 11   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 12   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 13   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 14   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 15   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 16   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 17   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 18   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 19   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 20   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 21  ETF de PFM Invesco Dividend Achievers Princ Po...            1
# 22   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 23   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 24  Visa Inc (V) VICE CHAIR & CFO Vasant M Prabhu ...            0
# 25   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 26   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 27   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 28   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 29   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 30   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 31  Visa Inc. to Participate in Upcoming Investor ...            0
# 32   Conservative Buy Rankings  $MSFT  Microsoft C...            0
# 33   Conservative Buy Rankings  $FB  Facebook Inc....            0
# 34  Mis TOP5 mejores compañías LARGE CAP GROWTH la...            0
# 35  Mis TOP5 mejores compañías LARGE CAP GROWTH la...            1
#
#     retweet_num  like_num  polarity_spacy
# 0             2         6        0.214286
# 1             5         9        1.000000
# 2             3         7        0.000000
# 3             4         4        0.388095
# 4             0         0        0.000000
# 5             1         9        0.214286
# 6             0         0        0.000000
# 7             1         0        0.000000
# 8             0         0        0.000000
# 9             0         0        0.000000
# 10            1         0        0.000000
# 11            0         0        0.000000
# 12            0         0        0.000000
# 13            1         0        0.000000
# 14            2         2        0.000000
# 15            0         0        0.000000
# 16            0         0        0.000000
# 17            0         0        0.000000
# 18            1         0        0.000000
# 19            1         0        0.000000
# 20            0         0        0.000000
# 21            2         3        0.000000
# 22            0         0        0.000000
# 23            0         0        0.000000
# 24            0         1        0.000000
# 25            1         0        0.000000
# 26            1         0        0.000000
# 27            0         0        0.000000
# 28            0         0        0.000000
# 29            0         0        0.000000
# 30            0         0        0.000000
# 31            0         0        0.000000
# 32            1         0        0.000000
# 33            0         0        0.000000
# 34            0         3        0.214286
# 35            2        12        0.214286

# %%
df['polarity_spacy'].mean()
# Out:
# 0.06236772486772487

# %%
import streamlit as sl

# %%
sl.write('test')
# Out:
# 2021-07-12 03:14:05.989
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/adrienfontaine/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py [ARGUMENTS]
